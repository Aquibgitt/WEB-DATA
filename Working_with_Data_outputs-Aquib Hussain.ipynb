# %% [markdown]
#                                      Project-2 WORKING_ON_WEB_DATA
#                                      Aquib_Hussain_Mohammed.

# %% [markdown]
# Part 1: XML Parsing Fetched from the NBC_NEWS

# %%
from src.web_data.nbc_news import sitemap_Parser
base_website = "https://www.nbcnews.com/"
sitemap_Parser = sitemap_Parser(base_website)

# %%
robots_txt = sitemap_Parser.fetch_robots_txt()
display(robots_txt)
sitemap_Parser.extract_sitemaps(robots_txt)
sitemap_df = sitemap_Parser.parse_sitemaps_to_dataframe()

if sitemap_df is not None:
    print(sitemap_df)  # Display the rows of the DataFrame
# Out:
# 'User-agent: *\nDisallow: /search/\nDisallow: /pages/search/\nDisallow: /pages/news-connect\nDisallow: /error404.aspx\nDisallow: /widget/\nDisallow: /*ns/local_news*\nDisallow: /bentoapi/\n\nDisallow: /*?*canonicalCard=\nUser-agent: Twitterbot\nAllow: /*?*canonicalCard=\n\n# Disallow ChatGPT\nUser-agent: GPTBot\nDisallow: /\n\nSitemap: https://www.nbcnews.com/sitemap/nbcnews/sitemap-index\nSitemap: https://www.nbcnews.com/sitemap/nbcnews/sitemap-news\nSitemap: https://www.nbcnews.com/sitemap/nbcnews/sitemap-curations\nSitemap: https://www.nbcnews.com/sitemap/nbcnews/sitemap-select.xml\nSitemap: https://www.nbcnews.com/politics/election-results/sitemap.xml'
#                                                     URL
# 0     https://www.nbcnews.com/sitemap/nbcnews/sitema...
# 1     https://www.nbcnews.com/sitemap/nbcnews/sitema...
# 2     https://www.nbcnews.com/sitemap/nbcnews/sitema...
# 3     https://www.nbcnews.com/sitemap/nbcnews/sitema...
# ...

# %% [markdown]
# Descrition-
#
# NBC is the home broadcaster of some of the longest continuously running American television series, including the news program Meet the Press (debuted 1947); Today (debuted 1952); The Tonight Show (debuted nationally 1954); and Saturday Night Live (debuted 1975).
#
# The Parse XML task is used when you have an XML document stored in a string or binary field. This task produces a tree representation of the XML that can be used by subsequent tasks in the mediation flow.
# The dataset comprises NBC News URLs, encompassing diverse content from articles to images. Employing web scraping techniques, I aim to extract article titles, descriptions, and images for analysis. Categorizing URLs by content types (e.g., articles, videos) could unveil distribution insights. URL structure analysis might reveal NBC News' content organization, while status checks could identify active or removed links. Network analysis of these URLs may uncover interconnections between NBC News web pages, utilizing scraping tools and HTTP request libraries for exploration.

# %% [markdown]
# Part 2: Using an API

# %% [markdown]
# Fetching the Data from Earthquake.usgs.gov by Using API and Performing the EDA.

# %%
from src.web_data import earthquake_api
from src.web_data.earthquake_api import usgs_Earthquake_Fetcher
earthquake_fetcher = usgs_Earthquake_Fetcher("2020-01-01", "2020-01-02")

# %%
# To fetch the EarthQuake Data 

earthquake_data = earthquake_fetcher.fetch_data()
earthquake_df = earthquake_fetcher.parse_to_dataframe(earthquake_data)

if earthquake_df is not None:
    print(earthquake_df)  # Display the rows of the DataFrame
# Out:
#      Magnitude                                    Place   Latitude  \
# 0         1.30               38 km SE of Tanana, Alaska  64.892200
# 1         1.63                10km ENE of Blackhawk, CA  37.845500
# 2         1.46                 14km S of Tres Pinos, CA  36.670667
# 3         1.56         7 km SW of Tallaboa, Puerto Rico  17.945500
# 4         1.78         6 km SSE of Guánica, Puerto Rico  17.913600
# ..         ...                                      ...        ...
# 606       1.64   8 km SSE of Maria Antonia, Puerto Rico  17.906600
# 607       1.84   9 km SSE of Maria Antonia, Puerto Rico  17.899300
# 608       1.81  12 km SSE of Maria Antonia, Puerto Rico  17.870500
# 609       2.55          64 km N of Isabela, Puerto Rico  19.076600
# 610       2.75          80 km N of Isabela, Puerto Rico  19.217500
#
#       Longitude  Depth
# 0   -151.595200   2.50
# 1   -121.794333  12.65
# 2   -121.294500   5.04
# 3    -66.762300   8.00
# 4    -66.884000   3.00
# ...

# %% [markdown]
# The United States Geological Survey (USGS), founded as the Geological Survey, is an agency of the United States government whose work spans the disciplines of biology, geography, geology, and hydrology. The agency was founded on March 3, 1879, to study the landscape of the United States, its natural resources, and the natural hazards that threaten it. The agency also makes maps of extraterrestrial planets and moons based on data from U.S. space probes.
# The Above Data contains 611 Rows with 5 columns with Magnitude, Place, Latitude, Longitude, Depth from which we can gain insights by performing the EDA operation.

# %% [markdown]
#                                                The Exploratory Data Analysis

# %%
from src.web_data.earthquake_api import eda_Summary

# %%
Eda = usgs_Earthquake_Fetcher.parse_to_dataframe('','')
# Out:
# No earthquake data found.

# %%
eda_Summary.display_basic_info(earthquake_df)
# Out:
# Shape of the DataFrame: (611, 5)
#
# Info about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Magnitude  611 non-null    float64
#  1   Place      611 non-null    object
#  2   Latitude   611 non-null    float64
#  3   Longitude  611 non-null    float64
#  4   Depth      611 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 24.0+ KB
# None
#
# Summary statistics:
#         Magnitude    Latitude   Longitude       Depth
# count  611.000000  611.000000  611.000000  611.000000
# mean     1.912864   28.433316  -91.835779   15.834239
# std      1.033861   18.477492   56.639587   30.940313
# min     -0.500000  -53.090700 -179.275200   -1.750000
# 25%      1.210000   17.909550 -120.389550    5.000000
# 50%      1.790000   19.279000  -68.689500    7.570000
# 75%      2.320000   37.233550  -66.889850   12.100000
# ...

# %% [markdown]
# Here's the display of the basic information about the dataset fetched from the API displaying the shape,info and the Summary stats.

# %%
#To Get the Histogram for Magnitude
eda_Summary.plot_histogram(earthquake_df)

# %%
eda_Summary.plot_depth_histogram(earthquake_df)

# %% [markdown]
# The Above Histograms specify the Magnitude and Depth of the Earthquakes against the Frequency,the Magnitude is highest in the richter scale which is above 80,
# and the depth is the highest at the point 0 and where the frequency is 500. which means that most of the earthquakes occured in the depth 0 and the Magnitude is between 1,2

# %%
eda_Summary.plot_latitude_longitude(earthquake_df)

# %% [markdown]
# Above Scatter plot specifies the Earthquake locations according to the latitude and longitude as we can see that the population gathering is grouped at a place where it is -150 and -100

# %%
eda_Summary.plot_top_places(earthquake_df)

# %% [markdown]
# The Above Graph gives us the horizantal barplot which explains the Top 10 Highest frequency according to the places where everyplace is of Puerto Rico in which 8km Guanica stands the highest and 6km SSE stands the least in the TOP 10.

# %%
eda_Summary.plot_magnitude_ranges(earthquake_df)

# %% [markdown]
# Above Graph is against Magnitude Range and the frequency in counting the Magnitude Range,where 0-3 Magnitude range is the Highest.

# %%
eda_Summary.plot_pairplot_numerical(earthquake_df)

# %% [markdown]
# Here are some Subplots where there are scatterplots and Histograms for the different Attributes like Magnitude,Latitude,LOngitude,Depth to showcase their patterns.

# %%
eda_Summary.plot_violin_magnitude_by_depth(earthquake_df)

# %% [markdown]
# Above is the Violin PLot. The Violin plots provide a Visual representation of the data distribution, much like box plots but with added density estimation. They show the shape, spread, and central tendency of the data.
# Violin plots merge the benefits of box plots (which display quartiles, median, and outliers) with kernel density estimation (KDE), representing the probability density of the data at different values.Here is the plot between the Depth and Magnitude.

# %%
eda_Summary.plot_scatter_matrix_kde(earthquake_df)

# %% [markdown]
# This Plot Shows the KDE Scatter matrix of the Datasets Represented Above for which the Magnitude,Latitude,Longitude,Depth are shown in the Visual Representation.

# %%
eda_Summary.plot_correlation_matrix(earthquake_df)

# %% [markdown]
# Here's the HeatMap to findout the Correlation Matrix between all the four Attributes and which varies from -0.4 to 1.0.

# %% [markdown]
# Data Summary:_
#
# Overall, this dataset showcases earthquakes of various magnitudes, occurring across different geographical locations and depths. The distribution suggests a mix of minor to moderate earthquakes, with occasional occurrences of more significant seismic events.
#
# 1-The majority of earthquakes in this dataset have magnitudes below 2. The range of magnitudes is quite diverse, with a few stronger earthquakes (up to around magnitude 5) also recorded.
#
# 2-Earthquakes have occurred across various latitudes and longitudes, indicating a global distribution of seismic activity. The latitudinal range extends from southern latitudes to mid-latitudes.
#
# 3-The depth of earthquakes varies significantly, with most earthquakes occurring at depths less than 10 units. However, there are instances of earthquakes occurring at deeper levels, up to around 31 units.
#
# 4-The standard deviation values for magnitude and depth suggest considerable variability within the dataset, indicating a diverse range of earthquake intensities and depths.

# %% [markdown]
#             Part-3                   Web Scraping Using the Weather.gov

# %% [markdown]
# Webscraping essentially involves data extraction from websites, enabling an individual or an entity to retrieve and use information that may otherwise be difficult to gather manually

# %%
from src.web_data.web_scraping import weather_Scraper
## The Weather Data can be used like this by usin the below scraping tools.
weather_url = "https://forecast.weather.gov/MapClick.php?lat=40.714530000000025&lon=-74.00711999999999"
weather_scraper = weather_Scraper(weather_url)

# %%
html_content = weather_scraper.fetch_html()
weather_data = weather_scraper.scrape_weather_data(html_content)
weather_df = weather_scraper.create_dataframe(weather_data)

if weather_df is not None:
    print(weather_df)
# Out:
#           Period                     Short Description  Temperature
# 0      Overnight  Slight ChanceLight Rainand PatchyFog   Low: 46 °F
# 1       Saturday                            Patchy Fog  High: 55 °F
# 2  SaturdayNight     Slight ChanceRain thenRain Likely   Low: 54 °F
# 3         Sunday                                  Rain  High: 54 °F
# 4    SundayNight                           Rain Likely   Low: 48 °F
# 5         Monday                          Partly Sunny  High: 51 °F
# 6    MondayNight                         Partly Cloudy   Low: 41 °F
# 7        Tuesday                          Mostly Sunny  High: 46 °F
# 8   TuesdayNight                         Mostly Cloudy   Low: 38 °F

# %% [markdown]
# Data Summary-
#
# Overall, this dataset provides a concise view of anticipated weather conditions and temperature ranges across various time segments or days. It captures the diversity of weather patterns and temperature fluctuations expected during the forecasted periods.
#
# 1-The dataset includes various weather descriptions for different time periods, such as 'Mostly Cloudy', 'Partly Sunny then Chance Rain', 'Rain and Breezy', 'Mostly Sunny', 'Mostly Clear', etc., implying diverse weather conditions during different periods.
#
# 2- Temperatures vary across the periods, with highs ranging from 48°F to 58°F and lows ranging from 37°F to 49°F. The temperature data indicates fluctuations throughout the forecasted days or segments.
#
# 3- There seems to be a pattern of lower temperatures during 'Overnight' and 'Night' periods ('Low' temperatures) compared to the daytime ('High' temperatures), which is typical in weather forecasts.
#
# 4- Each day or time segment exhibits a distinct weather forecast, suggesting the possibility of varying weather conditions throughout the week or forecasted period.
#
# 5- The short descriptions provide concise insights into the expected weather conditions, enabling a quick understanding of the forecast for each period
#
# 6- The descriptions and temperature ranges offer a snapshot of the anticipated weather patterns, aiding in planning activities or understanding expected conditions across different times.

# %% [markdown]
# ## Conclusion
#
# #### XML Parsing:
# XML parsing involves extracting and manipulating data from XML files. It allows you to access and process structured data stored in XML format. Understanding XML parsing is crucial for handling data interchangeably between different systems. You likely learned how to navigate XML structures, extract specific elements or attributes, modify XML content, and write data back to XML files. This knowledge is essential for working with various data sources that utilize XML as their format.
#
# #### API Usage for Earthquake Data:
# Working with APIs (Application Programming Interfaces) gives you access to real-time or structured data from external services. By using an API to retrieve earthquake data, you likely gained insights into interacting with remote servers, making HTTP requests, handling JSON or XML responses, and extracting relevant earthquake information programmatically. This experience can be applied to accessing a wide range of APIs for diverse data needs in your projects.
#
# #### Web Scraping for Weather Data:
# Web scraping involves extracting information from websites. By scraping weather data, you likely acquired skills in navigating web pages, identifying relevant HTML elements, and extracting specific data such as temperature, forecasts, or weather patterns. Web scraping enables you to gather structured data from the web, which can be particularly useful for collecting information from websites that don't offer APIs or structured data access.
#
# In conclusion, your exploration of XML parsing, API usage for earthquake data retrieval, and web scraping for weather information equips you with diverse techniques for accessing, extracting, and manipulating data from various sources. These skills are foundational for data acquisition, enabling you to work with different data formats and sources effectively in your data analysis or research endeavors.

# %% [markdown]
# References

# %% [markdown]
# O'Reilly - "Hands-On Data Analysis": This resource likely offers a comprehensive guide or book focusing on practical aspects of data analysis. It might cover various topics related to data processing, manipulation, visualization, statistical analysis, and machine learning techniques using Python or other relevant tools.
#
# https://www.oreilly.com/library/view/hands-on-data-analysis/9781800563452/ - For working on the Data
#
# Wikipedia - Web Scraping: This Wikipedia page covers the concept of web scraping, a technique used to extract data from websites. It likely includes information about the methods, tools, legal aspects, and ethical considerations related to web scraping.
#
# Wikipedia-https://en.wikipedia.org/wiki/Web_scraping -  Web scrapiing parts
#
# Pluralsight - Parsing XML Documents with Python: This resource might offer a tutorial or course focused on parsing XML documents using Python programming language. It likely covers the basics of XML parsing, manipulating XML data, and using Python libraries to work with XML files, potentially within an AWS environment.
#
# https://www.pluralsight.com/cloud-guru/labs/aws/parsing-xml-documents-with-python?utm_source=bing&utm_medium=paid-search&utm_campaign=upskilling-and-reskilling&utm_term=ssi-na-bing-us-dynamic&utm_content=free-trial&msclkid=5635d75998d21096f5dcb204cad52430 - XML parsing.
